# %%
import pandas as pd
import numpy as np
import datetime
import names

# %%
def strTimeProp(start, end, format, prop):

    stime = time.mktime(time.strptime(start, format))
    etime = time.mktime(time.strptime(end, format))

    ptime = stime + prop * (etime - stime)

    return time.strftime(format, time.localtime(ptime))


def randomDate(start, end, prop):
    return strTimeProp(start, end, '%d/%m/%Y', prop)

# %%
id = [i for i in range(1, 101)]
name = [names.get_full_name() for i in range(100)]
birth_date = [randomDate("1/1/1940", "1/1/2005", random.random()) for i in range(100)]
taxpayer_registry = [random.randrange(10000000000, 50000000000) for i in range(100)]
registration_completed = [random.choice(['0', '1']) for i in range(100)]
gender = [random.choice(['M', 'F']) for i in range(100)]
mothers_name = [names.get_full_name(gender='female') for i in range(100)]
image_url = [None for i in range(100)]
registration_completed_at = [datetime.datetime.now() for i in range(100)]
created_at = [datetime.datetime.now() for i in range(100)]
updated_at = [datetime.datetime.now() for i in range(100)]

# %%
df = pd.DataFrame({
    'id' : id,
    'name' : name,
    'birth_date' :  birth_date,
    'taxpayer_registry' : taxpayer_registry,
    'registration_completed' : registration_completed,
    'gender' : gender,
    'mothers_name' : mothers_name,
    'image_url' : image_url,
    'registration_completed_at' : registration_completed_at,
    'created_at' : created_at,
    'updated_at' : updated_at
})

# %%
df
# Out:
#      id               name  birth_date  taxpayer_registry  \
# 0     1   Marissa Saunders  19/03/1997        16351923776
# 1     2       Jason Thorpe  11/09/1968        27443036779
# 2     3     Laura Criswell  22/06/1993        43438722621
# 3     4     Dorothy Kramer  21/02/1992        49505340521
# 4     5     Dewayne Skelly  07/01/1951        29881716914
# 5     6      Annita Oleary  30/11/1961        47113841341
# 6     7   Stephanie Miller  26/12/1958        15188879600
# 7     8      Jamal Jackson  27/03/1982        36485634000
# 8     9       Flora Hocker  27/06/1967        33997537130
# 9    10          Pat Rhyne  26/07/1941        35633808304
# 10   11      Joseph Turpin  08/02/1970        42155548548
# 11   12   Jennifer Sandler  02/07/1971        27966299553
# 12   13        Joe Carrick  28/03/1960        34106148924
# 13   14     Jennifer Smith  27/12/1954        27658635431
# 14   15       Barbara Dorn  09/08/1973        40179663903
# ...

# %%
df.to_csv('pacient.csv')
